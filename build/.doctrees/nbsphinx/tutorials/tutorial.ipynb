# %% [markdown]
# # Tutorial

# %%
import distorted as dt
import pandas as pd

# %% [markdown]
# In this file, a demonstration of some of the capabilities of ``Distorted`` will be provided.

# %%
df = pd.read_csv('data/SAEFigure14NonDimensional.csv')
sample = dt.Distortion(df)

# %%
sample.ARP1420()
# Out:
#    Span/ Ring #  Circumferential Intensity  Circumferential Extent (deg)  \
# 0        0.4472                   0.065182                    207.927928
# 1        0.6325                   0.087690                    178.738739
# 2        0.7746                   0.075559                    180.180180
# 3        0.8944                   0.079933                    180.180180
# 4        1.0000                   0.063488                    180.900901
#
#    Multiple Per Rev  Radial Intensity
# 0                 1          0.009486
# 1                 1         -0.011663
# 2                 1          0.001602
# 3                 1         -0.004030
# 4                 1          0.004605

# %%
sample.plot_quantity('Total Pressure')
