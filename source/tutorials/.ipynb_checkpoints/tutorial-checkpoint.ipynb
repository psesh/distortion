# %% [markdown]
# # Tutorial

# %%
import distorted as dt
import pandas as pd

# %% [markdown]
# In this file, a demonstration of some of the capabilities of ``Distorted`` will be provided.

# %%
# Still not completely sure why CSVToDataframe has to be a separate class.
df = pd.read_csv('data/figure15.csv')
sample = dt.Distortion(df)

# %%
sample.ARP1420()
# Out:
#    Span/ Ring #  Circumferential Intensity  Circumferential Extent (deg)  \
# 0             1                   0.002509                     94.774775
# 1             2                   0.010307                     94.774775
# 2             3                   0.005623                     58.378378
# 3             4                   0.003918                    192.072072
# 4             5                   0.004785                    178.738739
#
#    Multiple Per Rev  Radial Intensity
# 0          1.741851          0.057149
# 1          1.277856          0.037399
# 2          1.762317         -0.014350
# 3          1.000000         -0.050724
# 4          1.000000         -0.029474

# %%
sample.plot_quantity('Pressure')

# %%
# Span values seem incorrect?

# %%
df
# Out:
#     Probe  Span  Theta (radians)  Pressure (kPa)
# 0       1     1         0.000000           0.943
# 1       2     1         0.785398           0.944
# 2       3     1         1.570796           0.938
# 3       4     1         2.356194           0.942
# 4       5     1         3.141593           0.945
# 5       6     1         3.926991           0.946
# 6       7     1         4.712389           0.947
# 7       8     1         5.497787           0.938
# 8       9     2         0.000000           0.972
# 9      10     2         0.785398           0.955
# 10     11     2         1.570796           0.982
# 11     12     2         2.356194           0.967
# 12     13     2         3.141593           0.957
# 13     14     2         3.926991           0.968
# 14     15     2         4.712389           0.959
# 15     16     2         5.497787           0.941
# 16     17     3         0.000000           1.023
# 17     18     3         0.785398           1.013
# ...
