# %%
import distorted as dt
import pandas as pd

# %%
df = pd.read_csv('data/Ground vortex aerodynamics Figure10f.csv')
sample = dt.Distortion(df)

# %%
print(sample.getDF().to_string())
# Out:
#      Number    Span     Theta  Total Pressure  Static Pressure
# 0       0.0  0.0000  0.000000           0.000              NaN
# 1       NaN  0.1560  0.000000           0.000              NaN
# 2       NaN  0.2615  0.000000           0.000              NaN
# 3       NaN  0.3670  0.000000           0.000              NaN
# 4       NaN  0.4725  0.000000           0.000              NaN
# 5       NaN  0.5780  0.000000           0.000              NaN
# 6       NaN  0.6835  0.000000           0.000              NaN
# 7       NaN  0.7890  0.000000           0.000              NaN
# 8       NaN  0.8945  0.000000           0.000              NaN
# 9       NaN  1.0000  0.000000           0.000              NaN
# 10      1.0  0.0000  0.174533           0.000              NaN
# 11      NaN  0.1560  0.174533           0.000              NaN
# 12      NaN  0.2615  0.174533           0.000              NaN
# 13      NaN  0.3670  0.174533           0.000              NaN
# ...

# %%
sample.plot_quantity('Total Pressure')
