# %% [markdown]
# # Tutorial

# %%
import distorted as dt
import pandas as pd

# %% [markdown]
# In this file, a demonstration of some of the capabilities of ``Distorted`` will be provided.

# %%
df = pd.read_csv('data/figure15NonDimensional.csv')
sample = dt.Distortion(df)

# %%
sample.ARP1420()
# Out:
#    Span/ Ring #  Circumferential Intensity  Circumferential Extent (deg)  \
# 0        0.4472                   0.002509                     94.774775
# 1        0.6325                   0.010307                     94.774775
# 2        0.7746                   0.005623                     58.378378
# 3        0.8944                   0.003918                    192.072072
# 4        1.0000                   0.004785                    178.738739
#
#    Multiple Per Rev  Radial Intensity
# 0          1.741851          0.057149
# 1          1.277856          0.037399
# 2          1.762317         -0.014350
# 3          1.000000         -0.050724
# 4          1.000000         -0.029474

# %%
sample.plot_quantity('Total Pressure')

# %%
df
# Out:
#     Probe    Span  Theta (radians)  Pressure (kPa)
# 0       1  0.4472         0.000000           0.943
# 1       2  0.4472         0.785398           0.944
# 2       3  0.4472         1.570796           0.938
# 3       4  0.4472         2.356194           0.942
# 4       5  0.4472         3.141593           0.945
# 5       6  0.4472         3.926991           0.946
# 6       7  0.4472         4.712389           0.947
# 7       8  0.4472         5.497787           0.938
# 8       9  0.6325         0.000000           0.972
# 9      10  0.6325         0.785398           0.955
# 10     11  0.6325         1.570796           0.982
# 11     12  0.6325         2.356194           0.967
# 12     13  0.6325         3.141593           0.957
# 13     14  0.6325         3.926991           0.968
# 14     15  0.6325         4.712389           0.959
# 15     16  0.6325         5.497787           0.941
# 16     17  0.7746         0.000000           1.023
# 17     18  0.7746         0.785398           1.013
# 18     19  0.7746         1.570796           1.017
# 19     20  0.7746         2.356194           1.011
# 20     21  0.7746         3.141593           1.021
# 21     22  0.7746         3.926991           1.003
# 22     23  0.7746         4.712389           1.020
# 23     24  0.7746         5.497787           1.007
# 24     25  0.8944         0.000000           1.058
# 25     26  0.8944         0.785398           1.038
# 26     27  0.8944         1.570796           1.053
# 27     28  0.8944         2.356194           1.045
# 28     29  0.8944         3.141593           1.048
# 29     30  0.8944         3.926991           1.050
# 30     31  0.8944         4.712389           1.063
# 31     32  0.8944         5.497787           1.051
# 32     33  1.0000         0.000000           1.031
# 33     34  1.0000         0.785398           1.026
# 34     35  1.0000         1.570796           1.030
# 35     36  1.0000         2.356194           1.020
# 36     37  1.0000         3.141593           1.019
# 37     38  1.0000         3.926991           1.043
# 38     39  1.0000         4.712389           1.032
# 39     40  1.0000         5.497787           1.035
